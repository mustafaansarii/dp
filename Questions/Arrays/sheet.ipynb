# %%
import pandas as pd

data = {
    "Topic": ["Arrays & Strings"] * 45,
    "Question Title": [
        "Two Sum",
        "Merge Sorted Array",
        "Valid Anagram",
        "Move Zeroes",
        "Best Time to Buy and Sell Stock",
        "Contains Duplicate",
        "Rotate Array",
        "Plus One",
        "Intersection of Two Arrays",
        "Find the Missing Number",
        "Longest Substring Without Repeating Characters",
        "Container With Most Water",
        "Longest Palindromic Substring",
        "Product of Array Except Self",
        "Set Matrix Zeroes",
        "Spiral Matrix",
        "Group Anagrams",
        "Letter Combinations of a Phone Number",
        "3Sum",
        "Kadane's Algorithm",
        "Spiral Order Matrix II",
        "Minimum Swaps to Bring Elements Together",
        "Repeat and Missing Number",
        "Merge Overlapping Intervals",
        "First Missing Positive",
        "Sliding Window Maximum",
        "Median of Two Sorted Arrays",
        "Substring with Concatenation of All Words",
        "Maximum Subarray Sum II",
        "Game with Chips",
        "Sum of Digits Divisibility",
        "Berland Regional",
        "K-th Beautiful String",
        "Distinct Pairs",
        "Max Difference",
        "Permutation Exists",
        "Min Swaps to Sort",
        "Substrings with Exactly K Distinct Chars",
        "Triplets with Sum Smaller than Given Value",
        "Median of Running Stream",
        "Smallest Subarray with Given Sum",
        "Maximum Product Subarray",
        "Largest Rectangle in Histogram",
        "Next Permutation",
        "Word Search",
        "Find the Duplicate Number"
    ],
    "Difficulty": ["Easy"] * 10 + ["Medium"] * 14 + ["Hard"] * 21,
    "Question Link": [
        "leetcode.com/problems/two-sum/",
        "leetcode.com/problems/merge-sorted-array/",
        "leetcode.com/problems/valid-anagram/",
        "leetcode.com/problems/move-zeroes/",
        "leetcode.com/problems/best-time-to-buy-and-sell-stock/",
        "leetcode.com/problems/contains-duplicate/",
        "leetcode.com/problems/rotate-array/",
        "leetcode.com/problems/plus-one/",
        "leetcode.com/problems/intersection-of-two-arrays/",
        "geeksforgeeks.org/find-the-missing-number-in-a-sequence/",
        "leetcode.com/problems/longest-substring-without-repeating-characters/",
        "leetcode.com/problems/container-with-most-water/",
        "leetcode.com/problems/longest-palindromic-substring/",
        "leetcode.com/problems/product-of-array-except-self/",
        "leetcode.com/problems/set-matrix-zeroes/",
        "leetcode.com/problems/spiral-matrix/",
        "leetcode.com/problems/group-anagrams/",
        "leetcode.com/problems/letter-combinations-of-a-phone-number/",
        "leetcode.com/problems/3sum/",
        "geeksforgeeks.org/kadanes-algorithm/",
        "interviewbit.com/problems/spiral-order-matrix-ii/",
        "interviewbit.com/problems/minimum-swaps-required-to-bring-all-elements-less-than-or-equal-to-k-together/",
        "interviewbit.com/problems/repeat-and-missing-number-array/",
        "interviewbit.com/problems/merge-overlapping-intervals/",
        "leetcode.com/problems/first-missing-positive/",
        "leetcode.com/problems/sliding-window-maximum/",
        "leetcode.com/problems/median-of-two-sorted-arrays/",
        "leetcode.com/problems/substring-with-concatenation-of-all-words/",
        "codeforces.com/problemset/problem/1389/D",
        "codeforces.com/problemset/problem/1418/C",
        "codeforces.com/problemset/problem/1139/C",
        "codeforces.com/problemset/problem/1100/E",
        "codeforces.com/problemset/problem/1354/C",
        "codechef.com/problems/DISTPAIRS",
        "codechef.com/problems/MAXDIFF",
        "codechef.com/problems/PERMEXIS",
        "geeksforgeeks.org/minimum-number-of-swaps-required-to-sort-an-array/",
        "geeksforgeeks.org/count-number-of-substrings-with-exactly-k-distinct-characters/",
        "geeksforgeeks.org/count-triplets-with-sum-smaller-than-a-given-value/",
        "geeksforgeeks.org/median-of-stream-of-integers-running-integer-median/",
        "geeksforgeeks.org/smallest-subarray-with-sum-greater-than-a-given-value/",
        "geeksforgeeks.org/maximum-product-subarray/",
        "geeksforgeeks.org/largest-rectangle-in-histogram/",
        "leetcode.com/problems/next-permutation/",
        "leetcode.com/problems/word-search/",
        "leetcode.com/problems/find-the-duplicate-number/"
    ]
}

# Create DataFrame
arraydf = pd.DataFrame(data)
arraydf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 105
#       3 data = {
#       4     "Topic": ["Arrays & Strings"] * 45,
#       5     "Question Title": [
#    (...)    101     ]
#     102 }
#     104 # Create DataFrame
# --> 105 arraydf = pd.DataFrame(data)
#     106 arraydf
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
import pandas as pd

data = {
    "Topic": ["Arrays & Strings"] * 45,
    "Question Title": [
        "Two Sum",
        "Merge Sorted Array",
        "Valid Anagram",
        "Move Zeroes",
        "Best Time to Buy and Sell Stock",
        "Contains Duplicate",
        "Rotate Array",
        "Plus One",
        "Intersection of Two Arrays",
        "Find the Missing Number",
        "Longest Substring Without Repeating Characters",
        "Container With Most Water",
        "Longest Palindromic Substring",
        "Product of Array Except Self",
        "Set Matrix Zeroes",
        "Spiral Matrix",
        "Group Anagrams",
        "Letter Combinations of a Phone Number",
        "3Sum",
        "Kadane's Algorithm",
        "Spiral Order Matrix II",
        "Minimum Swaps to Bring Elements Together",
        "Repeat and Missing Number",
        "Merge Overlapping Intervals",
        "First Missing Positive",
        "Sliding Window Maximum",
        "Median of Two Sorted Arrays",
        "Substring with Concatenation of All Words",
        "Maximum Subarray Sum II",
        "Game with Chips",
        "Sum of Digits Divisibility",
        "Berland Regional",
        "K-th Beautiful String",
        "Distinct Pairs",
        "Max Difference",
        "Permutation Exists",
        "Min Swaps to Sort",
        "Substrings with Exactly K Distinct Chars",
        "Triplets with Sum Smaller than Given Value",
        "Median of Running Stream",
        "Smallest Subarray with Given Sum",
        "Maximum Product Subarray",
        "Largest Rectangle in Histogram",
        "Next Permutation",
        "Word Search",
        "Find the Duplicate Number"
    ],
    "Difficulty": ["Easy"] * 10 + ["Medium"] * 14 + ["Hard"] * 21,
    "Question Link": [
        "leetcode.com/problems/two-sum/",
        "leetcode.com/problems/merge-sorted-array/",
        "leetcode.com/problems/valid-anagram/",
        "leetcode.com/problems/move-zeroes/",
        "leetcode.com/problems/best-time-to-buy-and-sell-stock/",
        "leetcode.com/problems/contains-duplicate/",
        "leetcode.com/problems/rotate-array/",
        "leetcode.com/problems/plus-one/",
        "leetcode.com/problems/intersection-of-two-arrays/",
        "geeksforgeeks.org/find-the-missing-number-in-a-sequence/",
        "leetcode.com/problems/longest-substring-without-repeating-characters/",
        "leetcode.com/problems/container-with-most-water/",
        "leetcode.com/problems/longest-palindromic-substring/",
        "leetcode.com/problems/product-of-array-except-self/",
        "leetcode.com/problems/set-matrix-zeroes/",
        "leetcode.com/problems/spiral-matrix/",
        "leetcode.com/problems/group-anagrams/",
        "leetcode.com/problems/letter-combinations-of-a-phone-number/",
        "leetcode.com/problems/3sum/",
        "geeksforgeeks.org/kadanes-algorithm/",
        "interviewbit.com/problems/spiral-order-matrix-ii/",
        "interviewbit.com/problems/minimum-swaps-required-to-bring-all-elements-less-than-or-equal-to-k-together/",
        "interviewbit.com/problems/repeat-and-missing-number-array/",
        "interviewbit.com/problems/merge-overlapping-intervals/",
        "leetcode.com/problems/first-missing-positive/",
        "leetcode.com/problems/sliding-window-maximum/",
        "leetcode.com/problems/median-of-two-sorted-arrays/",
        "leetcode.com/problems/substring-with-concatenation-of-all-words/",
        "codeforces.com/problemset/problem/1389/D",
        "codeforces.com/problemset/problem/1418/C",
        "codeforces.com/problemset/problem/1139/C",
        "codeforces.com/problemset/problem/1100/E",
        "codeforces.com/problemset/problem/1354/C",
        "codechef.com/problems/DISTPAIRS",
        "codechef.com/problems/MAXDIFF",
        "codechef.com/problems/PERMEXIS",
        "geeksforgeeks.org/minimum-number-of-swaps-required-to-sort-an-array/",
        "geeksforgeeks.org/count-number-of-substrings-with-exactly-k-distinct-characters/",
        "geeksforgeeks.org/count-triplets-with-sum-smaller-than-a-given-value/",
        "geeksforgeeks.org/median-of-stream-of-integers-running-integer-median/",
        "geeksforgeeks.org/smallest-subarray-with-sum-greater-than-a-given-value/",
        "geeksforgeeks.org/maximum-product-subarray/",
        "geeksforgeeks.org/largest-rectangle-in-histogram/",
        "leetcode.com/problems/next-permutation/",
        "leetcode.com/problems/word-search/",
        "leetcode.com/problems/find-the-duplicate-number/"
    ]
}

# Create DataFrame
arraydf = pd.DataFrame(data)
arraydf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 105
#       3 data = {
#       4     "Topic": ["Arrays & Strings"] * 45,
#       5     "Question Title": [
#    (...)    101     ]
#     102 }
#     104 # Create DataFrame
# --> 105 arraydf = pd.DataFrame(data)
#     106 arraydf
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...
